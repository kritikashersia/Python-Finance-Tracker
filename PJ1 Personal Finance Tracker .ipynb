# %%
import numpy as np
import csv
# Read CSV file

file_path = r'D:\MY PROJECTS\APRIL Projects\Week 1 Python Funmdamentals + Numpy\Python Personal Finance Tracker W1\data.csv'
dates = []
categories = []
amounts = []
descriptions = []
with open(file_path, 'r') as file:
    reader = csv.reader(file)
    header = next(reader)       # skip header row
    for row in reader:
        dates.append(row[0])
        categories.append(row[1])
        amounts.append(float(row[2]))
        descriptions.append(row[3])
# Convert to NumPy arrays
amounts_arr     = np.array(amounts)
categories_arr  = np.array(categories)
dates_arr       = np.array(dates)
print(f"Loaded {len(amounts_arr)} records")
print(f"Columns: {header}")
# Out:
# Loaded 50 records
# Columns: ['Date', 'Category', 'Amount', 'Description']

# %%
# Overall Spending Stats

total = np.sum(amounts_arr)
average = np.mean(amounts_arr)
maximum = np.max(amounts_arr)
minimum = np.min(amounts_arr)
median = np.median(amounts_arr)
std_dev = np.std(amounts_arr) 
print(f"Total Spending   : ₹{total:,.2f}")
print(f"Average Spending : ₹{average:,.2f}")
print(f"Max Spending     : ₹{maximum:,.2f}")
print(f"Min Spending     : ₹{minimum:,.2f}")
print(f"Median Spending  : ₹{median:,.2f}")
print(f"Std Deviation    : ₹{std_dev:,.2f}")
# Out:
# Total Spending   : ₹38,940.00
# Average Spending : ₹778.80
# Max Spending     : ₹4,500.00
# Min Spending     : ₹150.00
# Median Spending  : ₹465.00
# Std Deviation    : ₹819.51

# %%
# Find the transactions with highest & lowest amount 
# using np.argmax() and np.argmin() to find the index of extreme values.

max_idx  = np.argmax(amounts_arr)
min_idx = np.argmin(amounts_arr)
print("Highest Transaction:")
print(f"  ₹{amounts_arr[max_idx]:,.2f} → {descriptions[max_idx]}")
print(f"  Date: {dates[max_idx]}  |  Category: {categories[max_idx]}")
print("\nLowest Transaction:")
print(f"  ₹{amounts_arr[min_idx]:,.2f} → {descriptions[min_idx]}")
print(f"  Date: {dates[min_idx]}  |  Category: {categories[min_idx]}")
# Out:
# Highest Transaction:
#   ₹4,500.00 → New smartphone case and earphones
#   Date: 2/16/2026  |  Category: Shopping
#
# Lowest Transaction:
#   ₹150.00 → Uber ride to office
#   Date: 1/3/2026  |  Category: Transport

# %%
# Find index of highest and lowest amounts
max_idx = np.argmax(amounts_arr)
min_idx = np.argmin(amounts_arr)

# Print highest transaction details
print("Highest Transaction:")
print("  Amount:", amounts_arr[max_idx])
print("  Description:", descriptions[max_idx])
print("  Date:", dates[max_idx])
print("  Category:", categories[max_idx])

# Print lowest transaction details
print("\nLowest Transaction:")
print("  Amount:", amounts_arr[min_idx])
print("  Description:", descriptions[min_idx])
print("  Date:", dates[min_idx])
print("  Category:", categories[min_idx])
# Out:
# Highest Transaction:
#   Amount: 4500.0
#   Description: New smartphone case and earphones
#   Date: 2/16/2026
#   Category: Shopping
#
# Lowest Transaction:
#   Amount: 150.0
#   Description: Uber ride to office
#   Date: 1/3/2026
#   Category: Transport

# %%
# Category-wise Breakdown
# Using boolean masking to filter amounts per category and compute grouped stats.

unique_cats = np.unique(categories_arr)
print(f"{'Category':<15} {'Total':>10} {'Average':>10} {'Max':>8} {'Count':>6}")
print("-" * 55)
for cat in unique_cats:
    mask = categories_arr == cat      # boolean mask
    cat_amounts = amounts_arr[mask]   # filtered amounts
    total = np.sum(cat_amounts)
    avg   = np.mean(cat_amounts)
    mx    = np.max(cat_amounts)
    count = len(cat_amounts)
    print(f"{cat:<15} ₹{total:>8,.0f} ₹{avg:>8,.0f} ₹{mx:>6,.0f} {count:>5}")
# Out:
# Category             Total    Average      Max  Count
# -------------------------------------------------------
# Entertainment   ₹   2,850 ₹     407 ₹   600     7
# Food            ₹   7,250 ₹     483 ₹ 1,200    15
# Health          ₹   4,700 ₹     783 ₹ 1,500     6
# Shopping        ₹  15,700 ₹   2,617 ₹ 4,500     6
# Transport       ₹   1,940 ₹     216 ₹   300     9
# Utilities       ₹   6,500 ₹     929 ₹ 1,200     7

# %%
# ── Percentile Analysis ──
for p in [25, 50, 75, 90]:
    val = np.percentile(amounts_arr, p)
    print(f"{p}th percentile : ₹{val:,.2f}")
print(f"\nInterpretation:")
print(f"  • 50% of your transactions are below ₹{np.percentile(amounts_arr, 50):,.0f}")
print(f"  • 75% of your transactions are below ₹{np.percentile(amounts_arr, 75):,.0f}")
print(f"  • 90% of your transactions are below ₹{np.percentile(amounts_arr, 90):,.0f}")
# Out:
# 25th percentile : ₹300.00
# 50th percentile : ₹465.00
# 75th percentile : ₹937.50
# 90th percentile : ₹1,620.00
#
# Interpretation:
#   • 50% of your transactions are below ₹465
#   • 75% of your transactions are below ₹938
#   • 90% of your transactions are below ₹1,620

# %%
# ── Spending Tiers using Boolean Operations ──
low  = amounts_arr[amounts_arr < 500]
mid  = amounts_arr[(amounts_arr >= 500) & (amounts_arr < 1000)]
high = amounts_arr[amounts_arr >= 1000]
print("Spending Tiers:")
print(f"  Low  (< ₹500)      : {len(low)} txns  → Total ₹{np.sum(low):,.0f}")
print(f"  Mid  (₹500–₹999)   : {len(mid)} txns  → Total ₹{np.sum(mid):,.0f}")
print(f"  High (≥ ₹1000)     : {len(high)} txns → Total ₹{np.sum(high):,.0f}")
# Out:
# Spending Tiers:
#   Low  (< ₹500)      : 26 txns  → Total ₹8,060
#   Mid  (₹500–₹999)   : 13 txns  → Total ₹9,080
#   High (≥ ₹1000)     : 11 txns → Total ₹21,800

# %%
# ── Month-wise Spending ──
months_arr = np.array([d.split('/')[0] for d in dates]) 
month_names = {'1': 'January', '2': 'February', '3': 'March'}
for m in np.unique(months_arr):
    mask = months_arr == m
    m_total = np.sum(amounts_arr[mask])
    m_count = np.sum(mask)
    m_avg   = np.mean(amounts_arr[mask])
    print(f"{month_names[m]:<12} : ₹{m_total:>8,.0f}  "
          f"({m_count} txns, avg ₹{m_avg:,.0f})")
# Out:
# January      : ₹  13,230  (20 txns, avg ₹662)
# February     : ₹  17,540  (17 txns, avg ₹1,032)
# March        : ₹   8,170  (13 txns, avg ₹628)

# %%
# Use np.argsort() to rank transactions by amount.
# ── Top 5 Most Expensive Transactions ──
sorted_indices = np.argsort(amounts_arr)[::-1]   # descending
top_5 = sorted_indices[:5]
print("Top 5 Expenses:")
for rank, idx in enumerate(top_5, 1):
    print(f"  {rank}. ₹{amounts_arr[idx]:>7,.0f} | {categories[idx]:<14} "
          f"| {descriptions[idx]}")


# ENUMERATE does this in one single line
# rank = 1
# for idx in top_5:
#    print(rank, ...)
#    rank += 1
# Out:
# Top 5 Expenses:
#   1. ₹  4,500 | Shopping       | New smartphone case and earphones
#   2. ₹  3,200 | Shopping       | New backpack and accessories
#   3. ₹  2,500 | Shopping       | New running shoes
#   4. ₹  2,100 | Shopping       | Sports equipment
#   5. ₹  1,800 | Shopping       | Winter jacket purchase

# %%
import numpy as np
import csv

# ══════════════════════════════════════════════════════════════
#                   READ CSV DATA
# ══════════════════════════════════════════════════════════════

dates, categories, amounts, descriptions = [], [], [], []
file_path = r'D:\MY PROJECTS\APRIL Projects\Week 1 Python Funmdamentals + Numpy\Python Personal Finance Tracker W1\data.csv'
with open(file_path, 'r') as file:
    reader = csv.reader(file)
    header = next(reader)
    for row in reader:
        dates.append(row[0])
        categories.append(row[1])
        amounts.append(float(row[2]))
        descriptions.append(row[3])

amounts_arr     = np.array(amounts)
categories_arr  = np.array(categories)
dates_arr       = np.array(dates)
months_arr      = np.array([d.split('/')[0] for d in dates])

# ══════════════════════════════════════════════════════════════
#                   FORMATTED SUMMARY REPORT
# ══════════════════════════════════════════════════════════════

print()
print("╔" + "═" * 62 + "╗")
print("║" + "   PERSONAL FINANCE TRACKER — NUMPY SUMMARY REPORT ".center(62) + "║")
print("║" + f"  Data Period: {dates[0]} to {dates[-1]}".center(62) + "║")
print("║" + f"  Total Records Analyzed: {len(amounts_arr)}".center(62) + "║")
print("╚" + "═" * 62 + "╝")


# ── SECTION 1: OVERALL SPENDING STATS ────────────────────────

total   = np.sum(amounts_arr)
average = np.mean(amounts_arr)
maximum = np.max(amounts_arr)
minimum = np.min(amounts_arr)
median  = np.median(amounts_arr)
std_dev = np.std(amounts_arr)

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 1: OVERALL SPENDING STATISTICS".ljust(62) + "│")
print("├" + "─" * 62 + "┤")
print("│" + f"    Total Spending        :  ₹{total:>10,.2f}".ljust(62) + "│")
print("│" + f"    Average per Txn       :  ₹{average:>10,.2f}".ljust(62) + "│")
print("│" + f"    Median Spending       :  ₹{median:>10,.2f}".ljust(62) + "│")
print("│" + f"    Standard Deviation    :  ₹{std_dev:>10,.2f}".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("│" + f"    Maximum Transaction   :  ₹{maximum:>10,.2f}".ljust(62) + "│")
print("│" + f"    Minimum Transaction   :  ₹{minimum:>10,.2f}".ljust(62) + "│")
print("│" + f"    Spending Range        :  ₹{(maximum - minimum):>10,.2f}".ljust(62) + "│")
print("└" + "─" * 62 + "┘")


# ── SECTION 2: HIGHEST & LOWEST TRANSACTIONS ─────────────────

max_idx = np.argmax(amounts_arr)
min_idx = np.argmin(amounts_arr)

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 2: EXTREME TRANSACTIONS".ljust(62) + "│")
print("├" + "─" * 62 + "┤")
print("│" + "".ljust(62) + "│")
print("│" + "    HIGHEST TRANSACTION:".ljust(62) + "│")
print("│" + f"       Amount      : ₹{amounts_arr[max_idx]:,.2f}".ljust(62) + "│")
print("│" + f"       Description : {descriptions[max_idx]}".ljust(62) + "│")
print("│" + f"       Date        : {dates[max_idx]}".ljust(62) + "│")
print("│" + f"       Category    : {categories[max_idx]}".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("│" + "    LOWEST TRANSACTION:".ljust(62) + "│")
print("│" + f"       Amount      : ₹{amounts_arr[min_idx]:,.2f}".ljust(62) + "│")
print("│" + f"       Description : {descriptions[min_idx]}".ljust(62) + "│")
print("│" + f"       Date        : {dates[min_idx]}".ljust(62) + "│")
print("│" + f"       Category    : {categories[min_idx]}".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("└" + "─" * 62 + "┘")


# ── SECTION 3: CATEGORY-WISE BREAKDOWN ───────────────────────

unique_cats = np.unique(categories_arr)

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 3: CATEGORY-WISE BREAKDOWN".ljust(62) + "│")
print("├" + "─" * 62 + "┤")
print("│" + f"    {'Category':<15} {'Total':>10} {'Average':>9} {'Max':>8} {'#Txns':>6}  ".ljust(62) + "│")
print("│" + "    " + "─" * 52 + "      │")

cat_totals = {}
for cat in unique_cats:
    mask = categories_arr == cat
    cat_amounts = amounts_arr[mask]
    t = np.sum(cat_amounts)
    a = np.mean(cat_amounts)
    mx = np.max(cat_amounts)
    c = len(cat_amounts)
    cat_totals[cat] = t
    print("│" + f"    {cat:<15} ₹{t:>8,.0f} ₹{a:>7,.0f} ₹{mx:>6,.0f} {c:>5}  ".ljust(62) + "│")

top_cat = max(cat_totals, key=cat_totals.get)
low_cat = min(cat_totals, key=cat_totals.get)

print("│" + "".ljust(62) + "│")
print("│" + f"    Highest Category : {top_cat} (₹{cat_totals[top_cat]:,.0f})".ljust(62) + "│")
print("│" + f"    Lowest Category  : {low_cat} (₹{cat_totals[low_cat]:,.0f})".ljust(62) + "│")
print("└" + "─" * 62 + "┘")


# ── SECTION 4: PERCENTILE ANALYSIS ───────────────────────────

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 4: PERCENTILE ANALYSIS".ljust(62) + "│")
print("├" + "─" * 62 + "┤")

for p in [25, 50, 75, 90]:
    val = np.percentile(amounts_arr, p)
    bar_len = int(p / 5)
    bar = "█" * bar_len + "░" * (18 - bar_len)
    print("│" + f"    {p:>3}th percentile : ₹{val:>8,.2f}  {bar}".ljust(62) + "│")

print("│" + "".ljust(62) + "│")
print("│" + f"    → 50% of transactions are below ₹{np.percentile(amounts_arr, 50):,.0f}".ljust(62) + "│")
print("│" + f"    → 90% of transactions are below ₹{np.percentile(amounts_arr, 90):,.0f}".ljust(62) + "│")
print("│" + f"    → Only 10% exceed ₹{np.percentile(amounts_arr, 90):,.0f}".ljust(62) + "│")
print("└" + "─" * 62 + "┘")


# ── SECTION 5: SPENDING TIERS ────────────────────────────────

low  = amounts_arr[amounts_arr < 500]
mid  = amounts_arr[(amounts_arr >= 500) & (amounts_arr < 1000)]
high = amounts_arr[amounts_arr >= 1000]

low_pct  = (np.sum(low) / total) * 100
mid_pct  = (np.sum(mid) / total) * 100
high_pct = (np.sum(high) / total) * 100

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 5: SPENDING TIERS".ljust(62) + "│")
print("├" + "─" * 62 + "┤")
print("│" + f"    {'Tier':<20} {'#Txns':>6} {'Total':>10} {'% Share':>9}   ".ljust(62) + "│")
print("│" + "    " + "─" * 49 + "     │")
print("│" + f"    {'Low  (< ₹500)':<20} {len(low):>5} ₹{np.sum(low):>8,.0f} {low_pct:>7.1f}%   ".ljust(62) + "│")
print("│" + f"    {'Mid  (₹500–₹999)':<20} {len(mid):>5} ₹{np.sum(mid):>8,.0f} {mid_pct:>7.1f}%   ".ljust(62) + "│")
print("│" + f"    {'High (≥ ₹1000)':<20} {len(high):>5} ₹{np.sum(high):>8,.0f} {high_pct:>7.1f}%   ".ljust(62) + "│")
print("│" + "".ljust(62) + "│")

# Visual bar chart
print("│" + "    Txn Count Distribution:".ljust(62) + "│")
print("│" + f"    Low  : {'█' * len(low)} ({len(low)})".ljust(62) + "│")
print("│" + f"    Mid  : {'█' * len(mid)} ({len(mid)})".ljust(62) + "│")
print("│" + f"    High : {'█' * len(high)} ({len(high)})".ljust(62) + "│")
print("└" + "─" * 62 + "┘")


# ── SECTION 6: MONTH-WISE SPENDING TREND ─────────────────────

month_names = {'1': 'January', '2': 'February', '3': 'March'}

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 6: MONTH-WISE SPENDING TREND".ljust(62) + "│")
print("├" + "─" * 62 + "┤")
print("│" + f"    {'Month':<12} {'Total':>10} {'#Txns':>7} {'Average':>10}    ".ljust(62) + "│")
print("│" + "    " + "─" * 43 + "           │")

month_totals = {}
for m in np.unique(months_arr):
    mask = months_arr == m
    m_total = np.sum(amounts_arr[mask])
    m_count = np.sum(mask)
    m_avg   = np.mean(amounts_arr[mask])
    month_totals[m] = m_total
    print("│" + f"    {month_names[m]:<12} ₹{m_total:>8,.0f} {m_count:>6} ₹{m_avg:>8,.0f}    ".ljust(62) + "│")

print("│" + "".ljust(62) + "│")

# Visual bar chart for months
max_month_total = max(month_totals.values())
print("│" + "    Monthly Spending Trend:".ljust(62) + "│")
for m in np.unique(months_arr):
    bar_len = int((month_totals[m] / max_month_total) * 25)
    bar = "█" * bar_len
    print("│" + f"    {month_names[m]:<10} {bar} ₹{month_totals[m]:,.0f}".ljust(62) + "│")

print("└" + "─" * 62 + "┘")


# ── SECTION 7: TOP 5 EXPENSES ────────────────────────────────

sorted_indices = np.argsort(amounts_arr)[::-1]
top_5 = sorted_indices[:5]

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 7: TOP 5 MOST EXPENSIVE TRANSACTIONS".ljust(62) + "│")
print("├" + "─" * 62 + "┤")

for rank, idx in enumerate(top_5, 1):
    print("│" + f"    {rank}. ₹{amounts_arr[idx]:>7,.0f} │ {categories[idx]:<14} │ {descriptions[idx][:25]}".ljust(62) + "│")

top5_total = np.sum(amounts_arr[top_5])
top5_pct = (top5_total / total) * 100
print("│" + "".ljust(62) + "│")
print("│" + f"    Combined Top 5 Total : ₹{top5_total:,.0f} ({top5_pct:.1f}% of all spending)".ljust(62) + "│")
print("└" + "─" * 62 + "┘")


# ── SECTION 8: KEY INSIGHTS & RECOMMENDATIONS ────────────────

print()
print("┌" + "─" * 62 + "┐")
print("│" + "  SECTION 8: KEY INSIGHTS & RECOMMENDATIONS".ljust(62) + "│")
print("├" + "─" * 62 + "┤")
print("│" + "".ljust(62) + "│")
print("│" + f"  1. Your biggest spending category is {top_cat}".ljust(62) + "│")
print("│" + f"     (₹{cat_totals[top_cat]:,.0f} = {(cat_totals[top_cat]/total)*100:.1f}% of total budget)".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("│" + f"  2. Average (₹{average:,.0f}) is much higher than Median (₹{median:,.0f})".ljust(62) + "│")
print("│" + "     → A few large purchases are inflating your average".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("│" + f"  3. {len(high)} High-tier transactions account for".ljust(62) + "│")
print("│" + f"     ₹{np.sum(high):,.0f} ({high_pct:.1f}% of total) — biggest savings opportunity".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("│" + f"  4. Top 5 purchases alone = ₹{top5_total:,.0f} ({top5_pct:.1f}% of budget)".ljust(62) + "│")
print("│" + "     All are in Shopping category — consider setting limits".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("│" + f"  5. Monthly trend: Spending decreased from ₹{month_totals['1']:,.0f}".ljust(62) + "│")
print("│" + f"     (Jan) to ₹{month_totals['3']:,.0f} (Mar) — a positive trend!".ljust(62) + "│")
print("│" + "".ljust(62) + "│")
print("└" + "─" * 62 + "┘")


# ── FOOTER ───────────────────────────────────────────────────

print()
print("╔" + "═" * 62 + "╗")
print("║" + "  NumPy Functions Used in This Report:".ljust(62) + "║")
print("║" + "  np.sum() • np.mean() • np.median() • np.std()".ljust(62) + "║")
print("║" + "  np.max() • np.min() • np.argmax() • np.argmin()".ljust(62) + "║")
print("║" + "  np.percentile() • np.unique() • np.argsort()".ljust(62) + "║")
print("║" + "  Boolean Masking • Array Indexing • Slicing".ljust(62) + "║")
print("╠" + "═" * 62 + "╣")
print("║" + "  Report Generated Using Python + NumPy".center(62) + "║")
print("║" + "  Data Source: data.csv".center(62) + "║")
print("╚" + "═" * 62 + "╝")
print()
# Out:
# ╔══════════════════════════════════════════════════════════════╗
# ║        PERSONAL FINANCE TRACKER — NUMPY SUMMARY REPORT       ║
# ║               Data Period: 1/2/2026 to 3/24/2026             ║
# ║                   Total Records Analyzed: 50                 ║
# ╚══════════════════════════════════════════════════════════════╝
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 1: OVERALL SPENDING STATISTICS                      │
# ├──────────────────────────────────────────────────────────────┤
# │    Total Spending        :  ₹ 38,940.00                      │
# │    Average per Txn       :  ₹    778.80                      │
# │    Median Spending       :  ₹    465.00                      │
# │    Standard Deviation    :  ₹    819.51                      │
# │                                                              │
# │    Maximum Transaction   :  ₹  4,500.00                      │
# │    Minimum Transaction   :  ₹    150.00                      │
# │    Spending Range        :  ₹  4,350.00                      │
# └──────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 2: EXTREME TRANSACTIONS                             │
# ├──────────────────────────────────────────────────────────────┤
# │                                                              │
# │    HIGHEST TRANSACTION:                                      │
# │       Amount      : ₹4,500.00                                │
# │       Description : New smartphone case and earphones        │
# │       Date        : 2/16/2026                                │
# │       Category    : Shopping                                 │
# │                                                              │
# │    LOWEST TRANSACTION:                                       │
# │       Amount      : ₹150.00                                  │
# │       Description : Uber ride to office                      │
# │       Date        : 1/3/2026                                 │
# │       Category    : Transport                                │
# │                                                              │
# └──────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 3: CATEGORY-WISE BREAKDOWN                          │
# ├──────────────────────────────────────────────────────────────┤
# │    Category             Total   Average      Max  #Txns      │
# │    ────────────────────────────────────────────────────      │
# │    Entertainment   ₹   2,850 ₹    407 ₹   600     7          │
# │    Food            ₹   7,250 ₹    483 ₹ 1,200    15          │
# │    Health          ₹   4,700 ₹    783 ₹ 1,500     6          │
# │    Shopping        ₹  15,700 ₹  2,617 ₹ 4,500     6          │
# │    Transport       ₹   1,940 ₹    216 ₹   300     9          │
# │    Utilities       ₹   6,500 ₹    929 ₹ 1,200     7          │
# │                                                              │
# │    Highest Category : Shopping (₹15,700)                     │
# │    Lowest Category  : Transport (₹1,940)                     │
# └──────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 4: PERCENTILE ANALYSIS                              │
# ├──────────────────────────────────────────────────────────────┤
# │     25th percentile : ₹  300.00  █████░░░░░░░░░░░░░          │
# │     50th percentile : ₹  465.00  ██████████░░░░░░░░          │
# │     75th percentile : ₹  937.50  ███████████████░░░          │
# │     90th percentile : ₹1,620.00  ██████████████████          │
# │                                                              │
# │    → 50% of transactions are below ₹465                      │
# │    → 90% of transactions are below ₹1,620                    │
# │    → Only 10% exceed ₹1,620                                  │
# └──────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 5: SPENDING TIERS                                   │
# ├──────────────────────────────────────────────────────────────┤
# │    Tier                  #Txns      Total   % Share          │
# │    ─────────────────────────────────────────────────     │
# │    Low  (< ₹500)           26 ₹   8,060    20.7%             │
# │    Mid  (₹500–₹999)        13 ₹   9,080    23.3%             │
# │    High (≥ ₹1000)          11 ₹  21,800    56.0%             │
# │                                                              │
# │    Txn Count Distribution:                                   │
# │    Low  : ██████████████████████████ (26)                    │
# │    Mid  : █████████████ (13)                                 │
# │    High : ███████████ (11)                                   │
# └──────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 6: MONTH-WISE SPENDING TREND                        │
# ├──────────────────────────────────────────────────────────────┤
# │    Month             Total   #Txns    Average                │
# │    ───────────────────────────────────────────           │
# │    January      ₹  13,230     20 ₹     662                   │
# │    February     ₹  17,540     17 ₹   1,032                   │
# │    March        ₹   8,170     13 ₹     628                   │
# │                                                              │
# │    Monthly Spending Trend:                                   │
# │    January    ██████████████████ ₹13,230                     │
# │    February   █████████████████████████ ₹17,540              │
# │    March      ███████████ ₹8,170                             │
# └──────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 7: TOP 5 MOST EXPENSIVE TRANSACTIONS                │
# ├──────────────────────────────────────────────────────────────┤
# │    1. ₹  4,500 │ Shopping       │ New smartphone case and e  │
# │    2. ₹  3,200 │ Shopping       │ New backpack and accessor  │
# │    3. ₹  2,500 │ Shopping       │ New running shoes          │
# │    4. ₹  2,100 │ Shopping       │ Sports equipment           │
# │    5. ₹  1,800 │ Shopping       │ Winter jacket purchase     │
# │                                                              │
# │    Combined Top 5 Total : ₹14,100 (36.2% of all spending)    │
# └──────────────────────────────────────────────────────────────┘
#
# ┌──────────────────────────────────────────────────────────────┐
# │  SECTION 8: KEY INSIGHTS & RECOMMENDATIONS                   │
# ├──────────────────────────────────────────────────────────────┤
# │                                                              │
# │  1. Your biggest spending category is Shopping               │
# │     (₹15,700 = 40.3% of total budget)                        │
# │                                                              │
# │  2. Average (₹779) is much higher than Median (₹465)         │
# │     → A few large purchases are inflating your average       │
# │                                                              │
# │  3. 11 High-tier transactions account for                    │
# │     ₹21,800 (56.0% of total) — biggest savings opportunity   │
# │                                                              │
# │  4. Top 5 purchases alone = ₹14,100 (36.2% of budget)        │
# │     All are in Shopping category — consider setting limits   │
# │                                                              │
# │  5. Monthly trend: Spending decreased from ₹13,230           │
# │     (Jan) to ₹8,170 (Mar) — a positive trend!                │
# │                                                              │
# └──────────────────────────────────────────────────────────────┘
#
# ╔══════════════════════════════════════════════════════════════╗
# ║  NumPy Functions Used in This Report:                        ║
# ║  np.sum() • np.mean() • np.median() • np.std()               ║
# ║  np.max() • np.min() • np.argmax() • np.argmin()             ║
# ║  np.percentile() • np.unique() • np.argsort()                ║
# ║  Boolean Masking • Array Indexing • Slicing                  ║
# ╠══════════════════════════════════════════════════════════════╣
# ║             Report Generated Using Python + NumPy            ║
# ║                     Data Source: data.csv                    ║
# ╚══════════════════════════════════════════════════════════════╝
